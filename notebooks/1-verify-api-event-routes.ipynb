# %%
import httpx

# %%
path = "/api/events"
base_url = "http://localhost:8000"
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8000/api/events'

# %%
requests = httpx.get(endpoint)
print(requests.json())
print(requests.status_code)
# Out:
# 307
